# %%
import json
import pandas as pd

# %%
# set pandas to display all the columns
pd.set_option('display.max_columns', None)

# %%
# load json file
with open('weather_data.json') as json_file:
    data = json.load(json_file)

# %%
# Extract the 'data' part from the json file and transform it into a DataFrame
df = pd.DataFrame(data['data'])

# display top 10 rows of dataframe
df.head(10)
# Out:
#    app_temp  azimuth  clouds       datetime  dewpt  dhi  dni  elev_angle  ghi
# 0      10.6      0.7     100  2022-01-01:05    8.2    0    0       -72.3    0  \
# 1      10.6     40.5     100  2022-01-01:06    8.2    0    0       -68.1    0
# 2      10.6     64.3     100  2022-01-01:07    8.9    0    0       -59.1    0
# 3      10.6     79.0     100  2022-01-01:08    8.2    0    0       -48.3    0
# 4      10.0     89.8     100  2022-01-01:09    8.8    0    0       -37.0    0
# 5      10.0     99.1     100  2022-01-01:10    9.4    0    0       -25.7    0
# 6      10.6    108.0     100  2022-01-01:11    9.4    0    0       -14.6    0
# 7      10.6    117.1     100  2022-01-01:12    9.4    0    0        -4.2    0
# 8      10.6    126.9     100  2022-01-01:13   10.0   38  326         5.5   59
# 9      11.1    138.1     100  2022-01-01:14    9.9   66  588        13.8  198
#
#   h_angle pod  precip  pres revision_status  rh   slp  snow  solar_rad  temp
# 0    None   n    0.00  1008           final  85  1013   0.0          0  10.6  \
# 1    None   n    0.00  1008           final  85  1013   0.0          0  10.6
# 2    None   n    0.50  1008           final  89  1013   0.0          0  10.6
# 3    None   n    0.00  1006           final  85  1012   0.0          0  10.6
# 4    None   n    0.00  1006           final  92  1011   0.0          0  10.0
# 5    None   n    0.00  1006           final  96  1011   0.0          0  10.0
# 6    None   n    0.25  1005           final  92  1010   0.0          0  10.6
# 7    None   n    0.50  1005           final  92  1010   0.0          0  10.6
# 8    None   d    0.75  1004           final  96  1010   0.0         42  10.6
# 9    None   d    1.00  1005           final  92  1009   0.0         79  11.1
#
#        timestamp_local        timestamp_utc          ts   uv  vis
# 0  2022-01-01T00:00:00  2022-01-01T05:00:00  1641013200  0.0   13  \
# 1  2022-01-01T01:00:00  2022-01-01T06:00:00  1641016800  0.0   14
# 2  2022-01-01T02:00:00  2022-01-01T07:00:00  1641020400  0.0   11
# 3  2022-01-01T03:00:00  2022-01-01T08:00:00  1641024000  0.0   11
# 4  2022-01-01T04:00:00  2022-01-01T09:00:00  1641027600  0.0   11
# 5  2022-01-01T05:00:00  2022-01-01T10:00:00  1641031200  0.0   11
# 6  2022-01-01T06:00:00  2022-01-01T11:00:00  1641034800  0.0    6
# 7  2022-01-01T07:00:00  2022-01-01T12:00:00  1641038400  0.0    8
# 8  2022-01-01T08:00:00  2022-01-01T13:00:00  1641042000  0.4    5
# 9  2022-01-01T09:00:00  2022-01-01T14:00:00  1641045600  0.4    5
#
#                                              weather  wind_dir  wind_gust_spd
# 0  {'icon': 'c04n', 'description': 'Overcast clou...       195            3.6  \
# 1  {'icon': 'c04n', 'description': 'Overcast clou...       175            3.6
# 2  {'icon': 'c04n', 'description': 'Overcast clou...       150            3.6
# 3  {'icon': 'c04n', 'description': 'Overcast clou...       130            3.6
# 4  {'icon': 'c04n', 'description': 'Overcast clou...       150            4.4
# 5  {'icon': 'c04n', 'description': 'Overcast clou...       150            4.4
# 6  {'icon': 'c04n', 'description': 'Overcast clou...       150            4.8
# 7  {'icon': 'c04n', 'description': 'Overcast clou...       165            4.0
# 8  {'icon': 'r01d', 'description': 'Light rain', ...       185            4.0
# 9  {'icon': 'r01d', 'description': 'Light rain', ...       200            4.0
#
#    wind_spd
# 0       1.6
# 1       2.0
# 2       1.6
# 3       2.6
# 4       2.1
# 5       2.0
# 6       2.1
# 7       2.0
# 8       2.1
# 9       1.5

# %% [raw]
# # app_temp: Apparent/"Feels Like" temperature (default Celsius)
# # azimuth: Solar azimuth angle (degrees).
# # clouds: cloud coverage (%)
# # datetime: Date UTC (YYYY-MM-DD:HH).
# # dewpt: Dew point (default Celsius)
# # dhi: Diffuse horizontal solar irradiance (W/m^2) [Clear Sky]
# # dni: Direct normal solar irradiance (W/m^2) [Clear Sky]
# # elev_angle: Solar elevation angle (degrees)
# # ghi: Global horizontal solar irradiance (W/m^2) [Clear Sky]
# # h_angle: [DEPRECATED] Solar hour angle (degrees)
# # pod: Part of the day (d = day / n = night)
# # precip: Accumulated liquid equivalent precipitation (default mm)
# # pres: Pressure (mb)
# # revision_status: Data revision status - interim (subject to revisions) or final
# # rh: Relative humidity (%)
# # slp: Sea level pressure (mb)
# # snow: Accumulated snowfall (default mm)
# # solar_rad: Estimated Solar Radiation (W/m^2)
# # temp: Temperature
# # timestamp_local: Timestamp at Local time
# # timestamp_utc: Timestamp at UTC time
# # ts: Timestamp (Unix Timestamp)
# # uv: UV Index (0-11+)
# # vis: Visibility (default KM)
# # weather:  {
# icon: Weather icon code.
# code: Weather code.
# description: Text weather description.
# }
# # wind_dir: Wind direction (degrees)
# # wind_gust_spd: Wind gust speed (Default m/s)
# # wind_spd: Wind speed (Default m/s)

# %% [raw]
# # app_temp: Apparent/"Feels Like" temperature (default Celsius)
# # datetime: Date UTC (YYYY-MM-DD:HH).
# # pod: Part of the day (d = day / n = night)
# # precip: Accumulated liquid equivalent precipitation (default mm)
# # rh: Relative humidity (%)
# # snow: Accumulated snowfall (default mm)
# # solar_rad: Estimated Solar Radiation (W/m^2)
# # temp: Temperature
# # vis: Visibility (default KM)
# # weather:  {
# icon: Weather icon code.
# code: Weather code.
# description: Text weather description.
# }
# # wind_spd: Wind speed (Default m/s)
